# %% [markdown]
# # Introduction
# In this project I explore, segment, and cluster the neighborhoods in the city of Toronto. The neighborhood data though is not readily available on the internet.

# %%
import numpy as np
import pandas as pd
import json
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
import lxml
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize
from sklearn.datasets.samples_generator import make_blobs
from bs4 import BeautifulSoup
# !conda install -c conda-forge geopy --yes
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ### To create the above dataframe:

# %%
# download data and parse it:
r = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
soup = BeautifulSoup(r.text, 'html.parser')
table=soup.find('table', attrs={'class':'wikitable sortable'})

#get headers:
headers=table.findAll('th')
for i, head in enumerate(headers): headers[i]=str(headers[i]).replace("<th>","").replace("</th>","").replace("\n","")

#Find all items and skip first one:
rows=table.findAll('tr')
rows=rows[1:len(rows)]

# skip all meta symbols and line feeds between rows:
for i, row in enumerate(rows): rows[i] = str(rows[i]).replace("\n</td></tr>","").replace("<tr>\n<td>","")

# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned
df=pd.DataFrame(rows)
df[headers] = df[0].str.split("</td>\n<td>", n = 2, expand = True) 
df.drop(columns=[0],inplace=True)

# skip not assigned boroughs:
df = df.drop(df[(df.Borough == "Not assigned")].index)
# give "Not assigned" Neighborhoods same name as Borough:
df.Neighbourhood.replace("Not assigned", df.Borough, inplace=True)

# copy Borough value to Neighborhood if NaN:
df.Neighbourhood.fillna(df.Borough, inplace=True)
# drop duplicate rows:
df=df.drop_duplicates()

# extract titles from columns
df.update(
    df.Neighbourhood.loc[
        lambda x: x.str.contains('title')
    ].str.extract('title=\"([^\"]*)',expand=False))

df.update(
    df.Borough.loc[
        lambda x: x.str.contains('title')
    ].str.extract('title=\"([^\"]*)',expand=False))

# delete Toronto annotation from Neighbourhood:
df.update(
    df.Neighbourhood.loc[
        lambda x: x.str.contains('Toronto')
    ].str.replace(", Toronto",""))
df.update(
    df.Neighbourhood.loc[
        lambda x: x.str.contains('Toronto')
    ].str.replace("\(Toronto\)",""))

# combine multiple neighborhoods with the same post code
df2 = pd.DataFrame({'Postcode':df.Postcode.unique()})
df2['Borough']=pd.DataFrame(list(set(df['Borough'].loc[df['Postcode'] == x['Postcode']])) for i, x in df2.iterrows())
df2['Neighborhood']=pd.Series(list(set(df['Neighbourhood'].loc[df['Postcode'] == x['Postcode']])) for i, x in df2.iterrows())
df2['Neighborhood']=df2['Neighborhood'].apply(lambda x: ', '.join(x))
df2.dtypes

df2
# Out:
#     Postcode                 Borough  \
# 0        M3A              North York
# 1        M4A              North York
# 2        M5A        Downtown Toronto
# 3        M6A              North York
# 4        M7A        Downtown Toronto
# 5        M9A  Queen's Park (Toronto)
# 6        M1B    Scarborough, Toronto
# 7        M3B              North York
# 8        M4B               East York
# 9        M5B        Downtown Toronto
# 10       M6B              North York
# 11       M9B               Etobicoke
# 12       M1C    Scarborough, Toronto
# 13       M3C              North York
# 14       M4C               East York
# 15       M5C        Downtown Toronto
# 16       M6C                    York
# 17       M9C               Etobicoke
# 18       M1E    Scarborough, Toronto
# 19       M4E            East Toronto
# 20       M5E        Downtown Toronto
# 21       M6E                    York
# 22       M1G    Scarborough, Toronto
# 23       M4G               East York
# 24       M5G        Downtown Toronto
# 25       M6G        Downtown Toronto
# 26       M1H    Scarborough, Toronto
# 27       M2H              North York
# 28       M3H              North York
# 29       M4H               East York
# 30       M5H        Downtown Toronto
# 43        Brockton, Parkdale Village, Exhibition Place
# 44                     Oakridge, Golden Mile, Clairlea
# 45                            Silver Hills, York Mills
# 46                                           Downsview
# 47                      India Bazaar, The Beaches West
# 48                      Commerce Court, Victoria Hotel
# 49                  Upwood Park, Downsview, North Park
# 50                                       Humber Summit
# 51     Cliffside, Scarborough Village West, Cliffcrest
# 52                             Willowdale, Newtonbrook
# 53                                   Downsview Central
# 54                                     Studio District
# 55                   Lawrence Manor East, Bedford Park
# 56      Mount Dennis, Silverthorn, Del Ray, Keelesdale
# 57                                    Emery, Humberlea
# 58                         Cliffside West, Birch Cliff
# 59                                    Willowdale South
# 60                                 Downsview Northwest
# 61                                       Lawrence Park
# 62                                            Roselawn
# 63                       Runnymede, The Junction North
# 64                                              Weston
# 65   Scarborough Town Centre, Wexford Heights, Dors...
# 66                                     York Mills West
# 67                                    Davisville North
# 68                 Forest Hill North, Forest Hill West
# 69                       The Junction South, High Park
# 70                                           Westmount
# 71                                   Maryvale, Wexford
# 72                                     Willowdale West
# 73                                  North Toronto West
# 74                 Yorkville, North Midtown, The Annex
# 75                              Parkdale, Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 77   St. Phillips, Martin Grove Gardens, Kingsview ...
# 78                                           Agincourt
# 79                                          Davisville
# 80                      Harbord, University of Toronto
# 81                                  Swansea, Runnymede
# 82   Tam O'Shanter – Sullivan, Clarks Corners, Sull...
# 83                         Summerhill East, Moore Park
# 84          Kensington Market, Grange Park , Chinatown
# 85   Steeles East, Agincourt North, Milliken, Ontar...
# 86   South Hill, Rathnelly, Summerhill West, Deer P...
# 87   Island airport, South Niagara, King and Spadin...
# 88        Mimico South, New Toronto, Humber Bay Shores
# 89   Silverstone, Albion Gardens, Beaumond Heights,...
# 90                                     L'Amoreaux West
# 91                                            Rosedale
# 92                     Stn A PO Boxes 25 The Esplanade
# 93                              Long Branch, Alderwood
# 94                                           Northwest
# 95                                         Upper Rouge
# 96                         St. James Town, Cabbagetown
# 97              Underground city, First Canadian Place
# 98       Old Mill North, The Kingsway, Montgomery Road
# 99                                Church and Wellesley
# 100  Business Reply Mail Processing Centre 969 Eastern
# 101  Kingsway Park South East, Humber Bay, Mimico, ...
# 102  Kingsway Park South West, The Queensway, Mimic...

# %%
print('Number of rows is: {}.'.format(df2.shape))
# Out:
# Number of rows is: (103, 3).

# %%
#add Geo-spatial data
df3 = pd.read_csv("http://cocl.us/Geospatial_data")
df3.rename(columns={'Postal Code':'Postcode'}, inplace=True)
df3.set_index("Postcode")
df2.set_index("Postcode")
toronto_data=pd.merge(df2, df3)
toronto_data.head()
# Out:
#   Postcode           Borough                      Neighborhood   Latitude  \
# 0      M3A        North York                         Parkwoods  43.753259
# 1      M4A        North York                  Victoria Village  43.725882
# 2      M5A  Downtown Toronto                       Regent Park  43.654260
# 3      M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4      M7A  Downtown Toronto                     Queen's Park   43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# #### Create map of Toronto using lat and longitite values

# %%
location_address = 'Toronto, ON, Canada'

geo_locator = Nominatim(user_agent='to_explorer')
locaiton = geolocator.geocode(location_address)
latitute = location.latitude
longitude = location.longitude
print('Toronto, ON, Canada coordinate are {}, {}.'.format(latitude, longitude))


map_toronto = folium.Map(location=[latitude, longitude], zoom_start=20)
# Out:
# Toronto, ON, Canada coordinate are 43.653963, -79.387207.
